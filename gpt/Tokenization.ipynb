# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
text="Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."
print(text)
print(len(text))
tokens=text.encode("utf-8")
tokens=list(map(int,tokens))
print(tokens)
print(len(tokens))
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# 445
# ...

# %%
#This function gets the individual tokens and their respective counts and returns a dictionary
def get_stats(tokens):
    count={}
    for i in range(len(tokens)-1):
        pairs=(tokens[i],tokens[i+1])
        count[pairs]=count.get(pairs,0)+1
    return count
#This function gets the key with the highest value
def max_key(count):
    K=()
    V=0
    for i in count.keys():
        if(count[i]>V):
            K=i
            V=count[i]
    return K
    
count=get_stats(tokens)
K=max_key(count)
print(K,count[K])
print((chr(116),chr(32)))
# Out:
# (116, 32) 16
# ('t', ' ')

# %%
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# ---
vocab_size = 276 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  print(f"merging {pair} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (116, 32) into a new token 256
# merging (111, 114) into a new token 257
# merging (32, 101) into a new token 258
# merging (105, 110) into a new token 259
# merging (109, 32) into a new token 260
# merging (100, 111) into a new token 261
# merging (32, 99) into a new token 262
# merging (115, 101) into a new token 263
# merging (116, 101) into a new token 264
# merging (105, 115) into a new token 265
# merging (108, 105) into a new token 266
# merging (105, 100) into a new token 267
# merging (108, 97) into a new token 268
# merging (113, 117) into a new token 269
# merging (257, 101) into a new token 270
# merging (261, 108) into a new token 271
# merging (111, 110) into a new token 272
# merging (117, 114) into a new token 273
# merging (101, 110) into a new token 274
# merging (105, 97) into a new token 275

# %%
print(len(tokens))
print(len(ids))
print('compression ratio:',(len(tokens)/len(ids)))
# Out:
# 445
# 329
# compression ratio: 1.3525835866261398

# %%
# Out:
#   Cell In[15], line 1
#     def decode
#               ^
# SyntaxError: expected '('
